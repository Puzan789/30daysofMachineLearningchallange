# %%
import pandas as pd

# %%
mydict={
    'name':['ram','shyam','hari'],
    'class':[3,4,5],
    "address":["ilam",'jhapa','brt']
}
df=pd.DataFrame(mydict)

# %%
df
# Out:
#     name  class address
# 0    ram      3    ilam
# 1  shyam      4   jhapa
# 2   hari      5     brt

# %%
try:
    file=open('data.csv','x')
except:
    print("error occured")

# %%
import csv

# %%
mydict=[{
    'name':['ram','shyam','hari'],
    'class':[3,4,5],
    "address":["ilam",'jhapa','brt']
}]
fields=['name','class','address']
file=open('data.csv','w')
writer=csv.DictWriter(file,fieldnames=fields)
writer.writeheader()
for i in mydict:
    writer.writerow(i)

# %%
mydict={
    'name':['ram','shyam','hari','shyam','harka','sampan','balen','ravi','sabse'],
    'class':[3,4,5,4,6,3,4,7,8],
    "address":["ilam",'jhapa','brt',"ilam",'jhapa','brt',"ilam",'jhapa','brt'],
    'rollno':[3,4,5,2,3,4,6,7,8]
}
df=pd.DataFrame(mydict)
df.to_csv('dataframes.csv',index=False)

# %%
df=pd.read_csv('dataframes.csv',usecols=['name','class','address'])

# %%
pd.melt(df)
# Out:
#    variable   value
# 0      name     ram
# 1      name   shyam
# 2      name    hari
# 3      name   shyam
# 4      name   harka
# 5      name  sampan
# 6      name   balen
# 7      name    ravi
# 8      name   sabse
# 9     class       3
# 10    class       4
# 11    class       5
# 12    class       4
# 13    class       6
# 14    class       3
# 15    class       4
# 16    class       7
# 17    class       8
# 18  address    ilam
# 19  address   jhapa
# 20  address     brt
# 21  address    ilam
# 22  address   jhapa
# 23  address     brt
# 24  address    ilam
# 25  address   jhapa
# 26  address     brt

# %%
df.loc[0:4,['name','class']]
# Out:
#     name  class
# 0    ram      3
# 1  shyam      4
# 2   hari      5
# 3  shyam      4
# 4  harka      6

# %%
df
# Out:
#      name  class address  rollno
# 0     ram      3    ilam       3
# 1   shyam      4   jhapa       4
# 2    hari      5     brt       5
# 3   shyam      4    ilam       2
# 4   harka      6   jhapa       3
# 5  sampan      3     brt       4
# 6   balen      4    ilam       6
# 7    ravi      7   jhapa       7
# 8   sabse      8     brt       8

# %%
df.drop('rollno',axis=1)
# Out:
#      name  class address
# 0     ram      3    ilam
# 1   shyam      4   jhapa
# 2    hari      5     brt
# 3   shyam      4    ilam
# 4   harka      6   jhapa
# 5  sampan      3     brt
# 6   balen      4    ilam
# 7    ravi      7   jhapa
# 8   sabse      8     brt

# %%
df.dropna()
# Out:
#      name  class address  rollno
# 0     ram      3    ilam       3
# 1   shyam      4   jhapa       4
# 2    hari      5     brt       5
# 3   shyam      4    ilam       2
# 4   harka      6   jhapa       3
# 5  sampan      3     brt       4
# 6   balen      4    ilam       6
# 7    ravi      7   jhapa       7
# 8   sabse      8     brt       8

# %%
df=pd.DataFrame([[1,2,3],
                [2,3,1],
                [4,5,6]],
               index=['1','2','3']
               ,columns=['a','b','c'])

# %%
df
# Out:
#    a  b  c
# 1  1  2  3
# 2  2  3  1
# 3  4  5  6

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'FRUITS'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df = pd.DataFrame(
[[4, 7, 10],
[5, 8, 11],
[6, 9, 12]],
index=[1, 2, 3],
columns=['a', 'b', 'c'])

# %%
df
# Out:
#    a  b   c
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3 entries, 1 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       3 non-null      int64
#  1   b       3 non-null      int64
#  2   c       3 non-null      int64
# dtypes: int64(3)
# memory usage: 96.0 bytes

# %%
mydict={'name':['ram','hari','shyam'],
       'class':[1,2,3]}
df=pd.DataFrame(mydict)

# %%
import csv

# %%
df.to_csv('recent.csv',index=False)

# %%
pd.read_csv('recent.csv')
# Out:
#     name  class
# 0    ram      1
# 1   hari      2
# 2  shyam      3

# %%
df=pd.read_csv('datas.csv',index_col='sn')

# %%
df.iloc[:,0:4]
# Out:
#    sn    name  age        add
# 0   1     Ram   45  Kathmandu
# 1   2   Shyam   34  Bhaktapur
# 2   3    Hari   45   lalitpur
# 3   4   Sabin   56      Jhapa
# 4   5  Nabina   23    Chitwan
# 5   6   Akash   22      Palpa

# %%
df.loc[:,['sn','name','age','add']]
# Out:
#    sn    name  age        add
# 0   1     Ram   45  Kathmandu
# 1   2   Shyam   34  Bhaktapur
# 2   3    Hari   45   lalitpur
# 3   4   Sabin   56      Jhapa
# 4   5  Nabina   23    Chitwan
# 5   6   Akash   22      Palpa

# %%
# Out:
#    sn    name  age        add       phone
# 0   1     Ram   45  Kathmandu  9808778765
# 1   2   Shyam   34  Bhaktapur  9808778765
# 2   3    Hari   45   lalitpur  9808443786
# 3   4   Sabin   56      Jhapa  9808778765
# 4   5  Nabina   23    Chitwan  9808738765
# 5   6   Akash   22      Palpa  9808889872

# %%
df.loc[2:5,['name','age','add']]
# Out:
#       name  age        add
# sn
# 2    Shyam   34  Bhaktapur
# 3     Hari   45   lalitpur
# 4    Sabin   56      Jhapa
# 5   Nabina   23    Chitwan

# %%
df
# Out:
#         sn  age        add       phone
# name
# Ram      1   45  Kathmandu  9808778765
# Shyam    2   34  Bhaktapur  9808778765
# Hari     3   45   lalitpur  9808443786
# Sabin    4   56      Jhapa  9808778765
# Nabina   5   23    Chitwan  9808738765
# Akash    6   22      Palpa  9808889872

# %%
df.loc['Ram':'Nabina',['sn','age']]
# Out:
#         sn  age
# name
# Ram      1   45
# Shyam    2   34
# Hari     3   45
# Sabin    4   56
# Nabina   5   23

# %%
df
# Out:
#         sn  age        add       phone
# name
# Ram      1   45  Kathmandu  9808778765
# Shyam    2   34  Bhaktapur  9808778765
# Hari     3   45   lalitpur  9808443786
# Sabin    4   56      Jhapa  9808778765
# Nabina   5   23    Chitwan  9808738765
# Akash    6   22      Palpa  9808889872

# %%
p=df['age']>20

# %%
df['name']
# Out:
# sn
# 1       Ram
# 2     Shyam
# 3      Hari
# 4     Sabin
# 5    Nabina
# 6     Akash
# Name: name, dtype: object

# %%
df['name'].tolist()
# Out:
# ['Ram', 'Shyam', 'Hari', 'Sabin', 'Nabina', 'Akash']

# %%
df[(df['name']=="Ram") & (df['add']=='Kathmandu')]
# Out:
#    name  age        add       phone
# sn
# 1   Ram   45  Kathmandu  9808778765

# %%
df[(df['age']>20) & (df['age']<30)]
# Out:
#       name  age      add       phone
# sn
# 5   Nabina   23  Chitwan  9808738765
# 6    Akash   22    Palpa  9808889872

# %%
df
# Out:
#       name  age        add       phone
# sn
# 1      Ram   45  Kathmandu  9808778765
# 2    Shyam   34  Bhaktapur  9808778765
# 3     Hari   45   lalitpur  9808443786
# 4    Sabin   56      Jhapa  9808778765
# 5   Nabina   23    Chitwan  9808738765
# 6    Akash   22      Palpa  9808889872

# %%
mydata={'name':['ram','shyam','hari'],'class':[1,2,4]}
df=pd.DataFrame(mydata)
df.to_csv("nameclass.csv",index=False)

# %%
pd.read_csv('nameclass.csv',index_col="class")
# Out:
#         name
# class
# 1        ram
# 2      shyam
# 4       hari

# %%
import csv

# %%
data=[['name','age','add'],
     ['ram',9,'bkt'],
     ['sram',19,'bk2t'],
     ['dram',39,'bk3t']]
file=open('ram.csv','w')
writer=csv.writer(file)
writer.writerows(data)
file.close()

# %%
pd.read_csv('ram.csv')
# Out:
#    name  age   add
# 0   ram    9   bkt
# 1  sram   19  bk2t
# 2  dram   39  bk3t

# %%
data=[{'name':'ram','age':9,"add":"raks"},
     {'name':'pram','age':943,"add":"rasdfks"},
     {'name':'dram','age':923,"add":"rasdfreks"}]
field=['name','age','add']
file=open("dict.csv",'w')
writer=csv.DictWriter(file,fieldnames=data[0].keys())
writer.writeheader()
writer.writerows(data)
file.close()

# %%
pd.read_csv('dict.csv')
# Out:
#    name  age        add
# 0   ram    9       raks
# 1  pram  943    rasdfks
# 2  dram  923  rasdfreks

# %%
data=[{'name':'ram','age':9,"add":"raks"},
     {'name':'pram','age':943,"add":"rasdfks"},
     {'name':'dram','age':923,"add":"rasdfreks"}]
data[0].keys()
# Out:
# dict_keys(['name', 'age', 'add'])
